# %% [markdown]
# <a href="https://colab.research.google.com/github/AIS-Tobe/Python_First-Steps/blob/main/Python_DS_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Escribe un código para instalar la versión 3.10.0 de la biblioteca matplotlib.
# !pip install matplotlib==3.10.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 41.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
# ...

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.10.0'

# %%
# Escribe un código para importar la biblioteca numpy con el alias np.
import numpy as np

# %%
# Crea un programa que lea la siguiente lista de números y elija uno al azar.
lista = [8, 12, 54, 23, 43, 1, 90, 87, 105, 77]
from random import choice, randint
choice(lista)
# Out:
# 12

# %%
# Crea un programa que genere aleatoriamente un número entero menor que 100.
randint(0,100)
# Out:
# 72

# %%
# Crea un programa que solicite a la persona usuaria ingresar dos números enteros y calcule la potencia del primer número elevado al segundo.
